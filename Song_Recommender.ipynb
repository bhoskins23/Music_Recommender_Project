# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances, cosine_distances, cosine_similarity
from sklearn.preprocessing import MinMaxScaler

# %%
pd.options.display.max_rows = 200

# %%
df = pd.read_csv("df_cleaned.csv")

# %%
df.drop(columns ='Unnamed: 0', inplace=True)

# %%
df.shape
# Out:
# (144166, 20)

# %%
# Makes it into an actual list instead of a string list
df['genres'] = df['genres'].apply(lambda x: x[1:-1].split(', '))

for i in df.index:
# filters out empty values in each list
    df['genres'].loc[i] = list(filter(None, df['genres'][i]))
# Out:
# /Users/brandonhoskins/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df
# Out:
#         acousticness        artists  danceability  energy  explicit  \
# 0             0.9910    Mamie Smith         0.598  0.2240         0
# 1             0.9930    Mamie Smith         0.647  0.1860         0
# 2             0.9920    Mamie Smith         0.782  0.0573         0
# 3             0.9950    Mamie Smith         0.482  0.2290         0
# 4             0.9920    Mamie Smith         0.574  0.1380         0
# ...              ...            ...           ...     ...       ...
# 144161        0.0292       Lil Xxel         0.748  0.4570         0
# 144162        0.2820       SPiCYSOL         0.608  0.3680         0
# 144163        0.8250        Lincoln         0.695  0.2320         0
# 144164        0.0205           RAYE         0.749  0.8200         0
# 144165        0.1250  Sfera Ebbasta         0.755  0.8820         1
#
#         instrumentalness  key  liveness  loudness  mode  \
# 0               0.000522    5    0.3790   -12.628     0
# 1               0.000018    0    0.5190   -12.098     1
# 2               0.000002    5    0.1760   -12.453     1
# 3               0.000061    7    0.5490   -12.619     1
# 4               0.000492    3    0.2330   -14.171     1
# ...                  ...  ...       ...       ...   ...
# 144161          0.000294    6    0.4440    -7.560     1
# 144162          0.000002    5    0.0908    -8.539     0
# 144163          0.000000    1    0.5900   -11.010     1
# 144164          0.000685    7    0.0775    -6.114     1
# 144165          0.001420   10    0.1030    -1.957     0
#
#                                                 song_name  song_popularity  \
# 0                                Keep A Song In Your Soul               12
# 1                                            Golfing Papa                4
# 2                            Don't You Advertise Your Man                5
# 3                   Kansas City Man Blues - 78rpm Version                4
# 4       Miss Jenny's Ball (aka There'll Be No Freebies...                1
# ...                                                   ...              ...
# 144161                                                LMK               71
# 144162  10years vintage - LiVE from 2020.3.5 @EBISU LI...               12
# 144163                                      Saint Bernard               68
# 144164                                         Regardless               76
# 144165                                               Baby                1
#
#         speechiness    tempo  valence  year  duration_min  \
# 0            0.0936  149.976    0.634  1920          2.81
# 1            0.1740   97.600    0.689  1920          2.73
# 2            0.0592   85.652    0.487  1920          3.25
# 3            0.0812   77.232    0.461  1920          3.30
# 4            0.1090  158.422    0.764  1920          3.16
# ...             ...      ...      ...   ...           ...
# 144161       0.0465  123.035    0.464  2020          3.14
# 144162       0.0278  125.941    0.212  2020          5.22
# 144163       0.0972  100.488    0.451  2020          1.72
# 144164       0.0478  120.066    0.534  2020          3.29
# 144165       0.0532   99.984    0.606  2021          3.23
#
#                                                    genres  artist_popularity  \
# 0         ["'harlem renaissance'", "'traditional blues'"]                  3
# 1         ["'harlem renaissance'", "'traditional blues'"]                  3
# 2         ["'harlem renaissance'", "'traditional blues'"]                  3
# 3         ["'harlem renaissance'", "'traditional blues'"]                  3
# 4         ["'harlem renaissance'", "'traditional blues'"]                  3
# ...                                                   ...                ...
# 144161                                      ["'pop r&b'"]                 71
# 144162                   ["'city pop'", "'japanese r&b'"]                 12
# 144163              ["'indie pop'", "'modern indie pop'"]                 68
# 144164  ["'dance pop'", "'pop'", "'pop dance'", "'post...                 80
# 144165  ["'italian hip hop'", "'italian pop'", "'trap ...                  1
#
#        song_decade
# 0            1920s
# 1            1920s
# 2            1920s
# 3            1920s
# 4            1920s
# ...            ...
# 144161       2020s
# 144162       2020s
# 144163       2020s
# 144164       2020s
# 144165       2020s
#
# [144166 rows x 20 columns]

# %%
df.describe()
# Out:
#         acousticness   danceability         energy       explicit  \
# count  144166.000000  144166.000000  144166.000000  144166.000000
# mean        0.493255       0.528681       0.492909       0.058370
# std         0.377425       0.176051       0.271451       0.234443
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.087400       0.407000       0.264000       0.000000
# 50%         0.504000       0.538000       0.482000       0.000000
# 75%         0.884000       0.657000       0.719000       0.000000
# max         0.996000       0.988000       1.000000       1.000000
#
#        instrumentalness            key       liveness       loudness  \
# count     144166.000000  144166.000000  144166.000000  144166.000000
# mean           0.183556       5.193825       0.209495     -11.502790
# std            0.324340       3.501892       0.182336       5.580913
# min            0.000000       0.000000       0.000000     -60.000000
# 25%            0.000001       2.000000       0.097900     -14.505000
# 50%            0.000457       5.000000       0.135000     -10.654000
# 75%            0.178000       8.000000       0.266000      -7.362000
# max            1.000000      11.000000       1.000000       3.744000
#
#                 mode  song_popularity    speechiness          tempo  \
# count  144166.000000    144166.000000  144166.000000  144166.000000
# mean        0.710181        29.692147       0.078120     117.436688
# std         0.453680        21.107551       0.109901      30.258919
# min         0.000000         0.000000       0.000000       0.000000
# 25%         0.000000        11.000000       0.034500      94.342500
# 50%         1.000000        30.000000       0.043800     115.793000
# 75%         1.000000        45.000000       0.068300     135.622000
# max         1.000000       100.000000       0.970000     243.507000
#
#              valence           year   duration_min  artist_popularity
# count  144166.000000  144166.000000  144166.000000      144166.000000
# mean        0.525736    1978.053071       3.919463          29.232628
# std         0.267660      24.552015       2.150613          18.386307
# min         0.000000    1920.000000       0.080000           0.000000
# 25%         0.306000    1959.000000       2.830000          14.000000
# 50%         0.536000    1978.000000       3.500000          31.000000
# 75%         0.751000    1997.000000       4.480000          42.000000
# max         1.000000    2021.000000      59.630000          91.000000

# %% [markdown]
# ### Scaling Song Measures

# %%
mm_scaler = MinMaxScaler()

# %%
song_data= df[['acousticness', 'danceability', 'energy', 'instrumentalness', 'key',
       'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'valence']]
song_data
# Out:
#         acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0             0.9910         0.598  0.2240          0.000522    5    0.3790
# 1             0.9930         0.647  0.1860          0.000018    0    0.5190
# 2             0.9920         0.782  0.0573          0.000002    5    0.1760
# 3             0.9950         0.482  0.2290          0.000061    7    0.5490
# 4             0.9920         0.574  0.1380          0.000492    3    0.2330
# ...              ...           ...     ...               ...  ...       ...
# 144161        0.0292         0.748  0.4570          0.000294    6    0.4440
# 144162        0.2820         0.608  0.3680          0.000002    5    0.0908
# 144163        0.8250         0.695  0.2320          0.000000    1    0.5900
# 144164        0.0205         0.749  0.8200          0.000685    7    0.0775
# 144165        0.1250         0.755  0.8820          0.001420   10    0.1030
#
#         loudness  mode  speechiness    tempo  valence
# 0        -12.628     0       0.0936  149.976    0.634
# 1        -12.098     1       0.1740   97.600    0.689
# 2        -12.453     1       0.0592   85.652    0.487
# 3        -12.619     1       0.0812   77.232    0.461
# 4        -14.171     1       0.1090  158.422    0.764
# ...          ...   ...          ...      ...      ...
# 144161    -7.560     1       0.0465  123.035    0.464
# 144162    -8.539     0       0.0278  125.941    0.212
# 144163   -11.010     1       0.0972  100.488    0.451
# 144164    -6.114     1       0.0478  120.066    0.534
# 144165    -1.957     0       0.0532   99.984    0.606
#
# [144166 rows x 11 columns]

# %%
song_features_sc = pd.DataFrame()
for col in song_data.columns:
    mm_scaler.fit(song_data[[col]])
    song_features_sc[col] = mm_scaler.transform(song_data[col].values.reshape(-1,1)).ravel() 
song_features_sc
# Out:
#         acousticness  danceability  energy  instrumentalness       key  \
# 0           0.994980      0.605263  0.2240          0.000522  0.454545
# 1           0.996988      0.654858  0.1860          0.000018  0.000000
# 2           0.995984      0.791498  0.0573          0.000002  0.454545
# 3           0.998996      0.487854  0.2290          0.000061  0.636364
# 4           0.995984      0.580972  0.1380          0.000492  0.272727
# ...              ...           ...     ...               ...       ...
# 144161      0.029317      0.757085  0.4570          0.000294  0.545455
# 144162      0.283133      0.615385  0.3680          0.000002  0.454545
# 144163      0.828313      0.703441  0.2320          0.000000  0.090909
# 144164      0.020582      0.758097  0.8200          0.000685  0.636364
# 144165      0.125502      0.764170  0.8820          0.001420  0.909091
#
#         liveness  loudness  mode  speechiness     tempo  valence
# 0         0.3790  0.743160   0.0     0.096495  0.615900    0.634
# 1         0.5190  0.751475   1.0     0.179381  0.400810    0.689
# 2         0.1760  0.745905   1.0     0.061031  0.351743    0.487
# 3         0.5490  0.743301   1.0     0.083711  0.317165    0.461
# 4         0.2330  0.718954   1.0     0.112371  0.650585    0.764
# ...          ...       ...   ...          ...       ...      ...
# 144161    0.4440  0.822666   1.0     0.047938  0.505263    0.464
# 144162    0.0908  0.807307   0.0     0.028660  0.517197    0.212
# 144163    0.5900  0.768543   1.0     0.100206  0.412670    0.451
# 144164    0.0775  0.845350   1.0     0.049278  0.493070    0.534
# 144165    0.1030  0.910564   0.0     0.054845  0.410600    0.606
#
# [144166 rows x 11 columns]

# %%
data_merge = df.drop(['acousticness', 'danceability',
       'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
       'speechiness', 'tempo', 'valence'], axis = 1)

final_df = data_merge.join(song_features_sc)
final_df
# Out:
#               artists  explicit  \
# 0         Mamie Smith         0
# 1         Mamie Smith         0
# 2         Mamie Smith         0
# 3         Mamie Smith         0
# 4         Mamie Smith         0
# ...               ...       ...
# 144161       Lil Xxel         0
# 144162       SPiCYSOL         0
# 144163        Lincoln         0
# 144164           RAYE         0
# 144165  Sfera Ebbasta         1
#
#                                                 song_name  song_popularity  \
# 0                                Keep A Song In Your Soul               12
# 1                                            Golfing Papa                4
# 2                            Don't You Advertise Your Man                5
# 3                   Kansas City Man Blues - 78rpm Version                4
# 4       Miss Jenny's Ball (aka There'll Be No Freebies...                1
# ...                                                   ...              ...
# 144161                                                LMK               71
# 144162  10years vintage - LiVE from 2020.3.5 @EBISU LI...               12
# 144163                                      Saint Bernard               68
# 144164                                         Regardless               76
# 144165                                               Baby                1
#
#         year  duration_min                                             genres  \
# 0       1920          2.81    ["'harlem renaissance'", "'traditional blues'"]
# 1       1920          2.73    ["'harlem renaissance'", "'traditional blues'"]
# 2       1920          3.25    ["'harlem renaissance'", "'traditional blues'"]
# 3       1920          3.30    ["'harlem renaissance'", "'traditional blues'"]
# 4       1920          3.16    ["'harlem renaissance'", "'traditional blues'"]
# ...      ...           ...                                                ...
# 144161  2020          3.14                                      ["'pop r&b'"]
# 144162  2020          5.22                   ["'city pop'", "'japanese r&b'"]
# 144163  2020          1.72              ["'indie pop'", "'modern indie pop'"]
# 144164  2020          3.29  ["'dance pop'", "'pop'", "'pop dance'", "'post...
# 144165  2021          3.23  ["'italian hip hop'", "'italian pop'", "'trap ...
#
#         artist_popularity song_decade  acousticness  danceability  energy  \
# 0                       3       1920s      0.994980      0.605263  0.2240
# 1                       3       1920s      0.996988      0.654858  0.1860
# 2                       3       1920s      0.995984      0.791498  0.0573
# 3                       3       1920s      0.998996      0.487854  0.2290
# 4                       3       1920s      0.995984      0.580972  0.1380
# ...                   ...         ...           ...           ...     ...
# 144161                 71       2020s      0.029317      0.757085  0.4570
# 144162                 12       2020s      0.283133      0.615385  0.3680
# 144163                 68       2020s      0.828313      0.703441  0.2320
# 144164                 80       2020s      0.020582      0.758097  0.8200
# 144165                  1       2020s      0.125502      0.764170  0.8820
#
#         instrumentalness       key  liveness  loudness  mode  speechiness  \
# 0               0.000522  0.454545    0.3790  0.743160   0.0     0.096495
# 1               0.000018  0.000000    0.5190  0.751475   1.0     0.179381
# 2               0.000002  0.454545    0.1760  0.745905   1.0     0.061031
# 3               0.000061  0.636364    0.5490  0.743301   1.0     0.083711
# 4               0.000492  0.272727    0.2330  0.718954   1.0     0.112371
# ...                  ...       ...       ...       ...   ...          ...
# 144161          0.000294  0.545455    0.4440  0.822666   1.0     0.047938
# 144162          0.000002  0.454545    0.0908  0.807307   0.0     0.028660
# 144163          0.000000  0.090909    0.5900  0.768543   1.0     0.100206
# 144164          0.000685  0.636364    0.0775  0.845350   1.0     0.049278
# 144165          0.001420  0.909091    0.1030  0.910564   0.0     0.054845
#
#            tempo  valence
# 0       0.615900    0.634
# 1       0.400810    0.689
# 2       0.351743    0.487
# 3       0.317165    0.461
# 4       0.650585    0.764
# ...          ...      ...
# 144161  0.505263    0.464
# 144162  0.517197    0.212
# 144163  0.412670    0.451
# 144164  0.493070    0.534
# 144165  0.410600    0.606
#
# [144166 rows x 20 columns]

# %% [markdown]
# ### Song Recommender Based On Song Measures

# %%
def song_recommender(data, song, artist, genre_parameter):
    song_and_artist_data = data[(data['artists'] == artist) & (data['song_name'] == song)].sort_values('year')[0:1]
    
    similarity_data = data.copy()
    
    data_values = similarity_data[['acousticness', 'danceability',
       'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
       'speechiness', 'tempo', 'valence']]
    
    similarity_data['similarity_with_song'] =cosine_similarity(data_values, data_values.to_numpy()[song_and_artist_data.index[0],None]).squeeze()
    
    artist_genres = set(*song_and_artist_data['genres'])

    similarity_data['genres'] = similarity_data['genres'].apply(lambda genres: list(set(genres).intersection(artist_genres)))
    
    similarity_lengths = similarity_data['genres'].str.len()
    similarity_data = similarity_data.reindex(similarity_lengths[similarity_lengths >= genre_parameter].sort_values(ascending=False).index)
    
    similarity_data = similarity_data[similarity_data['song_decade'] == song_and_artist_data['song_decade'].values[0]]
 
    similarity_data.rename(columns={'song_name': f'Similar Song to {song}'}, inplace=True)
    
    similarity_data = similarity_data.sort_values(by= 'similarity_with_song', ascending = False)
    
    similarity_data = similarity_data[['artists', f'Similar Song to {song}',
       'song_popularity', 'year', 'genres', 'artist_popularity', 'song_decade', 'similarity_with_song',
       'acousticness', 'danceability', 'energy', 'instrumentalness', 'key',
       'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'valence']]
    
    return similarity_data.head(10)

# %%
song_recommender(final_df, 'Over', 'Drake', 1)
# Out:
#                  artists             Similar Song to Over  song_popularity  \
# 102936             Drake                             Over               64
# 103025             Drake                             Over               59
# 88072            Dr. Dre                      Kush - Main               64
# 105671          Big Sean                          My Last               57
# 104499       Frank Ocean                       Crack Rock               59
# 104071      Jason Derulo                      Ridin' Solo               65
# 104084      Jason Derulo                      Ridin' Solo               56
# 100354  Gym Class Heroes  The Fighter (feat. Ryan Tedder)               59
# 104215         DJ Khaled       Welcome To My Hood - Remix               52
# 135839       Death Grips                          Get Got               59
#
#         year                                             genres  \
# 102936  2010  ["'hip hop'", "'rap'", "'canadian pop'", "'tor...
# 103025  2010  ["'hip hop'", "'rap'", "'canadian pop'", "'tor...
# 88072   2010                             ["'hip hop'", "'rap'"]
# 105671  2011                ["'hip hop'", "'rap'", "'pop rap'"]
# 104499  2012                                      ["'hip hop'"]
# 104071  2010                                      ["'pop rap'"]
# 104084  2010                                      ["'pop rap'"]
# 100354  2011                                      ["'pop rap'"]
# 104215  2011                ["'hip hop'", "'rap'", "'pop rap'"]
# 135839  2012                                      ["'hip hop'"]
#
#         artist_popularity song_decade  similarity_with_song  acousticness  \
# 102936                 63       2010s              1.000000      0.010743
# 103025                 63       2010s              0.998891      0.010944
# 88072                  52       2010s              0.996403      0.000624
# 105671                 53       2010s              0.993359      0.098394
# 104499                 63       2010s              0.992310      0.069880
# 104071                 67       2010s              0.991225      0.128514
# 104084                 67       2010s              0.991225      0.128514
# 100354                 62       2010s              0.990239      0.077811
# 104215                 62       2010s              0.989142      0.022189
# 135839                 56       2010s              0.989090      0.006305
#
#         danceability  energy  instrumentalness       key  liveness  loudness  \
# 102936      0.354251   0.845          0.000000  0.636364    0.1230  0.853194
# 103025      0.328947   0.848          0.000000  0.636364    0.1240  0.853241
# 88072       0.449393   0.866          0.000047  0.636364    0.1050  0.843734
# 105671      0.391700   0.773          0.000000  0.727273    0.2090  0.852080
# 104499      0.434211   0.736          0.000000  0.454545    0.0852  0.815496
# 104071      0.447368   0.830          0.000000  0.818182    0.1290  0.878200
# 104084      0.447368   0.830          0.000000  0.818182    0.1290  0.878200
# 100354      0.599190   0.926          0.000000  0.636364    0.1870  0.886844
# 104215      0.592105   0.815          0.000000  0.636364    0.1400  0.875329
# 135839      0.576923   0.993          0.007960  0.636364    0.0876  0.882326
#
#         mode  speechiness     tempo  valence
# 102936   1.0     0.206186  0.409200    0.450
# 103025   1.0     0.287629  0.411048    0.433
# 88072    1.0     0.114433  0.390001    0.375
# 105671   1.0     0.175258  0.322902    0.368
# 104499   1.0     0.228866  0.366569    0.379
# 104071   1.0     0.150515  0.366881    0.578
# 104084   1.0     0.150515  0.366881    0.578
# 100354   1.0     0.129897  0.406633    0.432
# 104215   1.0     0.235052  0.575248    0.541
# 135839   1.0     0.347423  0.357279    0.405

# %%
final_df.to_csv('final_df.csv')

# %%
final_df[['artists']]
# Out:
#               artists
# 0         Mamie Smith
# 1         Mamie Smith
# 2         Mamie Smith
# 3         Mamie Smith
# 4         Mamie Smith
# ...               ...
# 144161       Lil Xxel
# 144162       SPiCYSOL
# 144163        Lincoln
# 144164           RAYE
# 144165  Sfera Ebbasta
#
# [144166 rows x 1 columns]
